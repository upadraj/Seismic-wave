# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df_xtr = pd.read_csv("./data/balanced/x_train.csv")
df_ytr = pd.read_csv("./data/balanced/y_train.csv")
df_xtr["lables"] = df_ytr["S"]

# %%
df_xtr
# Out:
#          735    706    678    660    599    541    514    549    566    517  \
# 0       1009   1051   1083   1084   1066   1025    975   1088   1152   1011
# 1       1012    975   1077   1112   1109   1175   1157    957    938   1157
# 2       1048   1100   1182   1135   1129   1147   1028   1056   1110   1081
# 3     -49604 -49296 -49286 -49718 -50265 -50653 -51028 -51566 -52128 -52382
# 4      14801  13516  13160  13784  14999  16223  17224  17436  16437  15141
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 16298   1398   1728   1785   1834   1586   1449   1412   1258   1188   1003
# 16299   1133   1184   1190   1341   1230   1283   1367   1361   1541   1961
# 16300    169     96    214    248    -16   -242   -205     -1    143    311
# 16301   2687   2787   2877   2804   2401   2230   2181   2014   2304   2419
# 16302  -3392  -3713  -3590  -3145  -2894  -2941  -3209  -3408  -3559  -3695
#
# ...

# %%
print((df_xtr.shape, df_ytr.shape))
# Out:
# ((16303, 7204), (16303, 1))

# %%
train, test = train_test_split(df_xtr, test_size=0.1, shuffle=True)

# %%
train.to_csv("./data/balanced/train.csv", index=False)
test.to_csv("./data/balanced/test.csv",index=False)

# %%
train = pd.read_csv('./data/balanced/train.csv')

# %%
train
# Out:
#          735    706    678    660    599    541    514    549    566    517  \
# 0      37349  37391  37442  37469  37606  37556  37601  37801  37834  38099
# 1      -5373  -5374  -5420  -5404  -5387  -5389  -5372  -5376  -5392  -5430
# 2      -3415  -3393  -3405  -3387  -3404  -3357  -3394  -3352  -3342  -3377
# 3      -3179    382    835    -86  -3396  -1322   1528   1188   -615  -2586
# 4     -13212 -13322 -13376 -13432 -13507 -13542 -13643 -13754 -13833 -13974
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14667 -56226 -56110 -55940 -56003 -56689 -56672 -55826 -55979 -55894 -55825
# 14668   1934   3091   4226   4932   5298   5483   5173   4190   2736   1244
# 14669 -12544 -12621 -12621 -12623 -12604 -12580 -12569 -12625 -12683 -12685
# 14670 -43266 -43225 -43242 -43241 -43239 -43175 -43219 -43264 -43233 -43274
# 14671   -115      7    263    281    309     47   -381   -118    -10    425
#
# ...

# %%
test
# Out:
#          735    706    678    660    599    541    514    549    566    517  \
# 9022  -18414 -18627 -18868 -19089 -19336 -19591 -19825 -20053 -20273 -20506
# 14840  -1321  -1178  -1001   -893   -865   -862   -849   -838   -815   -768
# 5359   36432  38804  39128  40290  38352  41068  44060  38736  38164  39914
# 12780  29826  30026  30250  30445  30608  30958  31298  31509  31859  32149
# 13726  -2017  -2012  -1993  -1962  -1954  -1976  -1950  -1946  -1929  -1880
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 11384   -376   -517   -661   -775   -911  -1028  -1134  -1294  -1422  -1533
# 1180  -32492 -31854 -29377 -29900 -32002 -32245 -32091 -30925 -30805 -31661
# 10838  13786  10912  10979  10504  10014   5785    573  -3352  -6590  -7983
# 15564   -410     79    411    199    321   1370   1786   1128    300     17
# 5335   56764  53414  51321  48858  46893  47497  43057  42643  42599  40616
#
# ...
